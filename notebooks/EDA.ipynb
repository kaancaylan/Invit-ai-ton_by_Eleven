# %% [markdown]
# - First step is  regression, then we need to consider if the client will be attending the event and whether the increase in spending was due to the event or due to other factors such as christmas
# - Look at the correlation between premium (VIP) status and money spent
# - Look at the overall increase in spending after a social celebrity action
#
# ## Methodology
# Causal ML -->
# First step: Regression model to predict uplift (difference between purchases beforehand and afterwards)
# Second Model: Causality on the model feature "Event". Event is a binary feature on whether the person attended the event or not. We check the difference between the people who attended the event versus ones who didn't. We can also try a causal model.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_actions = pd.read_csv("data/actions.csv")
df_clients = pd.read_csv("data/clients.csv")
df_transactions = pd.read_csv("data/transactions.csv")

# %%
df_actions["action_type_label"].value_counts()
# Out:
# action_type_label
# Collection                 6730
# Social Celebrity Action    3176
# Business Treatment           93
# Lauch                         1
# Name: count, dtype: int64

# %%
df_actions["action_label"]
# Out:
# 0        Exclusive Offer
# 1        Exclusive Offer
# 2       Social Gathering
# 3       Social Gathering
# 4        Exclusive Offer
#               ...
# 9995     Exclusive Offer
# 9996     Exclusive Offer
# 9997     Exclusive Offer
# 9998     Exclusive Offer
# 9999     Exclusive Offer
# Name: action_label, Length: 10000, dtype: object

# %%
df_clients.isna().sum(), df_clients.shape
# Out:
# (client_id                                      0
#  client_country                              9656
#  client_gender                              16207
#  client_nationality                         16150
#  client_city                                18264
#  client_segment                                 0
#  client_premium_status                          0
#  client_is_phone_contactable                    0
#  client_is_email_contactable                    0
#  client_is_instant_messaging_contactable        0
#  client_is_contactable                          0
#  dtype: int64,
#  (28751, 11))

# %%
df_transactions.columns, df_clients.columns, df_actions.columns
# Out:
# (Index(['client_id', 'transaction_id', 'transaction_date', 'product_quantity',
#         'gross_amount_euro', 'product_category', 'product_subcategory',
#         'product_style'],
#        dtype='object'),
#  Index(['client_id', 'client_country', 'client_gender', 'client_nationality',
#         'client_city', 'client_segment', 'client_premium_status',
#         'client_is_phone_contactable', 'client_is_email_contactable',
#         'client_is_instant_messaging_contactable', 'client_is_contactable'],
#        dtype='object'),
#  Index(['action_id', 'action_type_label', 'action_subcategory_label',
#         'action_start_date', 'action_year', 'action_end_date',
#         'action_collection_year', 'action_collection', 'action_universe',
#         'action_category_label', 'action_channel', 'action_label', 'client_id',
#         'client_is_present', 'client_is_invited'],
#        dtype='object'))

# %% [markdown]
# ## Transaction data aggregation
# For every client, we will have a daily aggregated dataset. For every client, we have a daily spending and quantity
# - Feature extracted from transactions:
#     - Money spent
#     - Items purchased
#     - Favourite Product
#     - Favourite Style

# %%
df_transactions["client_id"].value_counts()
# Out:
# client_id
# c81328703    394
# c93212715    337
# c15284276    241
# c27492922    186
# c75296385    185
#             ...
# c04620334      1
# c67451642      1
# c16609876      1
# c92900730      1
# c54482513      1
# Name: count, Length: 13884, dtype: int64

# %%
df_transactions[["client_id", "transaction_date"]].value_counts()
# Out:
# client_id  transaction_date
# c70119140  2021-12-07          40
# c15284276  2021-12-05          28
# c54934148  2020-08-08          27
#            2020-03-12          26
# c48728989  2021-10-27          26
#                                ..
# c38031613  2021-09-22           1
#            2021-09-11           1
#            2021-09-09           1
#            2021-09-07           1
# c99997359  2021-11-23           1
# Name: count, Length: 34053, dtype: int64

# %%
df_transactions.head().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_522ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_522ab_level0_col0" class="col_heading level0 col0" >client_id</th>
#       <th id="T_522ab_level0_col1" class="col_heading level0 col1" >transaction_id</th>
#       <th id="T_522ab_level0_col2" class="col_heading level0 col2" >transaction_date</th>
#       <th id="T_522ab_level0_col3" class="col_heading level0 col3" >product_quantity</th>
#       <th id="T_522ab_level0_col4" class="col_heading level0 col4" >gross_amount_euro</th>
#       <th id="T_522ab_level0_col5" class="col_heading level0 col5" >product_category</th>
#       <th id="T_522ab_level0_col6" class="col_heading level0 col6" >product_subcategory</th>
#       <th id="T_522ab_level0_col7" class="col_heading level0 col7" >product_style</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_522ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_522ab_row0_col0" class="data row0 col0" >c17974679</td>
#       <td id="T_522ab_row0_col1" class="data row0 col1" >t11288118</td>
#       <td id="T_522ab_row0_col2" class="data row0 col2" >2020-07-25</td>
#       <td id="T_522ab_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_522ab_row0_col4" class="data row0 col4" >3044</td>
#       <td id="T_522ab_row0_col5" class="data row0 col5" >Women Ready-to-Wear</td>
#       <td id="T_522ab_row0_col6" class="data row0 col6" >Unknown</td>
#       <td id="T_522ab_row0_col7" class="data row0 col7" >Casual Style</td>
#     </tr>
#     <tr>
#       <th id="T_522ab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_522ab_row1_col0" class="data row1 col0" >c17974679</td>
#       <td id="T_522ab_row1_col1" class="data row1 col1" >t93389142</td>
#       <td id="T_522ab_row1_col2" class="data row1 col2" >2020-06-20</td>
#       <td id="T_522ab_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_522ab_row1_col4" class="data row1 col4" >569</td>
#       <td id="T_522ab_row1_col5" class="data row1 col5" >Women Accessory</td>
#       <td id="T_522ab_row1_col6" class="data row1 col6" >Unknown</td>
#       <td id="T_522ab_row1_col7" class="data row1 col7" >Stylish Fashion</td>
#     </tr>
#     <tr>
#       <th id="T_522ab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_522ab_row2_col0" class="data row2 col0" >c17974679</td>
#       <td id="T_522ab_row2_col1" class="data row2 col1" >t62924895</td>
#       <td id="T_522ab_row2_col2" class="data row2 col2" >2021-01-13</td>
#       <td id="T_522ab_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_522ab_row2_col4" class="data row2 col4" >7727</td>
#       <td id="T_522ab_row2_col5" class="data row2 col5" >Women Bags</td>
#       <td id="T_522ab_row2_col6" class="data row2 col6" >Unknown</td>
#       <td id="T_522ab_row2_col7" class="data row2 col7" >Leather</td>
#     </tr>
#     <tr>
#       <th id="T_522ab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_522ab_row3_col0" class="data row3 col0" >c17974679</td>
#       <td id="T_522ab_row3_col1" class="data row3 col1" >t93389142</td>
#       <td id="T_522ab_row3_col2" class="data row3 col2" >2020-06-20</td>
#       <td id="T_522ab_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_522ab_row3_col4" class="data row3 col4" >3954</td>
#       <td id="T_522ab_row3_col5" class="data row3 col5" >Women Ready-to-Wear</td>
#       <td id="T_522ab_row3_col6" class="data row3 col6" >Unknown</td>
#       <td id="T_522ab_row3_col7" class="data row3 col7" >Casual Style</td>
#     </tr>
#     <tr>
#       <th id="T_522ab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_522ab_row4_col0" class="data row4 col0" >c17974679</td>
#       <td id="T_522ab_row4_col1" class="data row4 col1" >t33368160</td>
#       <td id="T_522ab_row4_col2" class="data row4 col2" >2021-05-03</td>
#       <td id="T_522ab_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_522ab_row4_col4" class="data row4 col4" >1541</td>
#       <td id="T_522ab_row4_col5" class="data row4 col5" >Women Ready-to-Wear</td>
#       <td id="T_522ab_row4_col6" class="data row4 col6" >bottom segment</td>
#       <td id="T_522ab_row4_col7" class="data row4 col7" >Casual Style</td>
#     </tr>
#   </tbody>
# </table>

# %%
    

trans_gr = df_transactions.groupby(["client_id", "transaction_date"]).agg({
    'product_quantity': 'sum',
    'gross_amount_euro':'sum',
    'product_category': [lambda x: x.mode().iloc[0], lambda x: len(x.value_counts())],
    'product_style': [lambda x: x.mode(), lambda x: len(x.value_counts())],
})

trans_gr.columns = ["nr_items_purchased", "money_spent", "favorite_category", "nr_categories_purchased", "favorite_style", "nr_styles_purchased"]
trans_gr = trans_gr.reset_index(drop=False)
trans_gr
# Out:
#        client_id transaction_date  nr_items_purchased  money_spent  \
# 0      c00029531       2020-09-25                   1          546
# 1      c00029531       2020-10-04                   1         4652
# 2      c00029531       2021-03-15                   1         1483
# 3      c00055636       2018-07-20                   1          620
# 4      c00055636       2018-12-19                   1         2278
# ...          ...              ...                 ...          ...
# 34048  c99978675       2018-06-02                   1         2471
# 34049  c99978675       2018-12-07                   1         3897
# 34050  c99989096       2020-12-28                   1          984
# 34051  c99995560       2018-07-13                   1         3926
# 34052  c99997359       2021-11-23                   1         1065
#
#                favorite_category  nr_categories_purchased   favorite_style  \
# 0                Women Accessory                        1  Stylish Fashion
# 1      Women Small Leather Goods                        1     Canvas Style
# 2                Women Accessory                        1          Leather
# 3                Women Accessory                        1  Stylish Fashion
# 4                       Men Bags                        1     Canvas Style
# ...                          ...                      ...              ...
# 34048        Women Ready-to-Wear                        1        Day Style
# 34049        Women Ready-to-Wear                        1    Unknown Style
# 34050            Women Accessory                        1  Stylish Fashion
# 34051                 Women Bags                        1          Leather
# 34052                   Men Bags                        1        N/A Style
#
#        nr_styles_purchased
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        1
# ...                    ...
# 34048                    1
# 34049                    1
# 34050                    1
# 34051                    1
# 34052                    1
#
# [34053 rows x 8 columns]

# %%
df_transactions.groupby(["client_id", "transaction_date"]).apply()

# %% [markdown]
# # Merge

# %%
df = pd.merge(df_transactions, df_clients, on="client_id", how="inner")
df = pd.merge(df, df_actions, on="client_id", how="outer")
df
# Out:
#        client_id transaction_id transaction_date  product_quantity  \
# 0      c00015183            NaN              NaN               NaN
# 1      c00027842            NaN              NaN               NaN
# 2      c00029531      t54964130       2021-03-15               1.0
# 3      c00029531      t54964130       2021-03-15               1.0
# 4      c00029531      t33011136       2020-10-04               1.0
# ...          ...            ...              ...               ...
# 88714  c99986266            NaN              NaN               NaN
# 88715  c99986588            NaN              NaN               NaN
# 88716  c99989096      t27112485       2020-12-28               1.0
# 88717  c99995560      t75693702       2018-07-13               1.0
# 88718  c99997359      t65970244       2021-11-23               1.0
#
#        gross_amount_euro           product_category product_subcategory  \
# 0                    NaN                        NaN                 NaN
# 1                    NaN                        NaN                 NaN
# 2                 1483.0            Women Accessory             Unknown
# 3                 1483.0            Women Accessory             Unknown
# 4                 4652.0  Women Small Leather Goods             Unknown
# ...                  ...                        ...                 ...
# 88714                NaN                        NaN                 NaN
# 88715                NaN                        NaN                 NaN
# 88716              984.0            Women Accessory             Unknown
# 88717             3926.0                 Women Bags             Unknown
# 88718             1065.0                   Men Bags             Unknown
#
#          product_style client_country client_gender  ... action_year  \
# 0                  NaN            NaN           NaN  ...      2021.0
# 1                  NaN            NaN           NaN  ...      2021.0
# 2              Leather             KR             F  ...      2020.0
# 3              Leather             KR             F  ...      2021.0
# 4         Canvas Style             KR             F  ...      2020.0
# ...                ...            ...           ...  ...         ...
# 88714              NaN            NaN           NaN  ...      2021.0
# 88715              NaN            NaN           NaN  ...      2020.0
# 88716  Stylish Fashion            NaN             F  ...         NaN
# 88717          Leather             IT             F  ...         NaN
# 88718        N/A Style            NaN           NaN  ...         NaN
#
#       action_end_date  action_collection_year  action_collection  \
# 0          2021-01-31                  2021.0      Retail Action
# 1          2021-07-17                  2021.0    Fall Collection
# 2          2020-10-02                  2020.0  Winter Collection
# 3          2021-07-17                  2021.0    Fall Collection
# 4          2020-10-02                  2020.0  Winter Collection
# ...               ...                     ...                ...
# 88714      2021-12-09                  2021.0      Retail Action
# 88715      2020-05-14                  2020.0  ABCDER Collection
# 88716             NaN                     NaN                NaN
# 88717             NaN                     NaN                NaN
# 88718             NaN                     NaN                NaN
#
#        action_universe  action_category_label  action_channel  \
# 0      Women's Fashion                 Retail        In store
# 1      Women's Fashion                 Retail             NaN
# 2        Men's Fashion                 Retail        In store
# 3      Women's Fashion                 Retail             NaN
# 4        Men's Fashion                 Retail        In store
# ...                ...                    ...             ...
# 88714  Women's Fashion                 Retail        In store
# 88715  Women's Fashion                 Retail        In store
# 88716              NaN                    NaN             NaN
# 88717              NaN                    NaN             NaN
# 88718              NaN                    NaN             NaN
#
#                      action_label client_is_present client_is_invited
# 0      Lunar New Year Celebration               0.0               1.0
# 1                 Exclusive Offer               0.0               1.0
# 2                 Exclusive Offer               0.0               1.0
# 3                 Exclusive Offer               0.0               1.0
# 4                 Exclusive Offer               0.0               1.0
# ...                           ...               ...               ...
# 88714         Holiday Celebration               1.0               1.0
# 88715            Social Gathering               0.0               1.0
# 88716                         NaN               NaN               NaN
# 88717                         NaN               NaN               NaN
# 88718                         NaN               NaN               NaN
#
# [88719 rows x 32 columns]

# %%
df.isna().sum()
# Out:
# client_id                                      0
# transaction_id                              4929
# transaction_date                            4929
# product_quantity                            4929
# gross_amount_euro                           4929
# product_category                            4929
# product_subcategory                         4929
# product_style                               4939
# client_country                              9491
# client_gender                              11886
# client_nationality                         11721
# client_city                                18331
# client_segment                              4929
# client_premium_status                       4929
# client_is_phone_contactable                 4929
# client_is_email_contactable                 4929
# client_is_instant_messaging_contactable     4929
# client_is_contactable                       4929
# action_id                                  11489
# action_type_label                          11489
# action_subcategory_label                   11489
# action_start_date                          11489
# action_year                                11489
# action_end_date                            11489
# action_collection_year                     11489
# action_collection                          11504
# action_universe                            11489
# action_category_label                      11489
# action_channel                             22569
# action_label                               11489
# client_is_present                          11489
# client_is_invited                          11489
# dtype: int64

# %%
df["client_is_invited"] = df["client_is_invited"].fillna(0)
df["client_is_present"] = df["client_is_present"].fillna(0)

# %%
df["client_is_present"].value_counts(), df["client_is_invited"].value_counts()
# Out:
# (client_is_present
#  1.0    65397
#  0.0    23322
#  Name: count, dtype: int64,
#  client_is_invited
#  1.0    77230
#  0.0    11489
#  Name: count, dtype: int64)

# %%
df[["client_is_invited", "client_is_present"]].value_counts()
# Out:
# client_is_invited  client_is_present
# 1.0                1.0                  65397
#                    0.0                  11833
# 0.0                0.0                  11489
# Name: count, dtype: int64

# %%
pd.crosstab(df["client_is_invited"], df["client_is_present"])
# Out:
# client_is_present    0.0    1.0
# client_is_invited
# 0.0                11489      0
# 1.0                11833  65397

# %%
((df["client_is_present"]==1) & (df["client_is_invited"]==1)).sum() / df["client_is_invited"].sum()
# Out:
# 0.8467823384695067

# %% [markdown]
# # From src

# %%
import os
os.chdir("..")
os.getcwd()
# Out:
# '/Users/Dell/Desktop/HEC/Invit-ai-ton_by_Eleven'

# %%
from src.preprocessor import get_and_merge_data

# %%
PARENT_DIR = "data/"
df = get_and_merge_data(PARENT_DIR)
df
# Out:
#        client_id transaction_id transaction_date  product_quantity  \
# 0      c17974679      t11288118       2020-07-25                 1
# 1      c17974679      t93389142       2020-06-20                 1
# 2      c17974679      t62924895       2021-01-13                 1
# 3      c17974679      t93389142       2020-06-20                 1
# 4      c17974679      t33368160       2021-05-03                 1
# ...          ...            ...              ...               ...
# 83785  c36938015      t19758562       2021-07-03                 1
# 83786  c19544295      t83687427       2021-12-27                 1
# 83787  c07447234      t31595753       2021-05-27                 1
# 83788  c08145778      t79698899       2021-11-02                 1
# 83789  c54482513      t94462221       2022-01-12                 1
#
#        gross_amount_euro     product_category product_subcategory  \
# 0                   3044  Women Ready-to-Wear             Unknown
# 1                    569      Women Accessory             Unknown
# 2                   7727           Women Bags             Unknown
# 3                   3954  Women Ready-to-Wear             Unknown
# 4                   1541  Women Ready-to-Wear      bottom segment
# ...                  ...                  ...                 ...
# 83785               2220          Woman Shoes             Unknown
# 83786               6472           Women Bags             Unknown
# 83787                111      Women Accessory      bottom segment
# 83788               1220      Women Accessory             Unknown
# 83789                550      Women Accessory             Unknown
#
#          product_style client_country client_gender  ... action_year  \
# 0         Casual Style             DE             F  ...      2020.0
# 1      Stylish Fashion             DE             F  ...      2020.0
# 2              Leather             DE             F  ...      2020.0
# 3         Casual Style             DE             F  ...      2020.0
# 4         Casual Style             DE             F  ...      2020.0
# ...                ...            ...           ...  ...         ...
# 83785   Easy Day Style             DE             M  ...         NaN
# 83786          Leather             JP           NaN  ...         NaN
# 83787    Fashion Style             US             F  ...         NaN
# 83788  Stylish Fashion             AU             F  ...         NaN
# 83789  Stylish Fashion             AE           NaN  ...         NaN
#
#       action_end_date  action_collection_year  action_collection  \
# 0          2020-03-09                  2020.0  Winter Collection
# 1          2020-03-09                  2020.0  Winter Collection
# 2          2020-03-09                  2020.0  Winter Collection
# 3          2020-03-09                  2020.0  Winter Collection
# 4          2020-03-09                  2020.0  Winter Collection
# ...               ...                     ...                ...
# 83785             NaN                     NaN                NaN
# 83786             NaN                     NaN                NaN
# 83787             NaN                     NaN                NaN
# 83788             NaN                     NaN                NaN
# 83789             NaN                     NaN                NaN
#
#        action_universe  action_category_label  action_channel  \
# 0      Women's Fashion                 Client   Outside venue
# 1      Women's Fashion                 Client   Outside venue
# 2      Women's Fashion                 Client   Outside venue
# 3      Women's Fashion                 Client   Outside venue
# 4      Women's Fashion                 Client   Outside venue
# ...                ...                    ...             ...
# 83785              NaN                    NaN             NaN
# 83786              NaN                    NaN             NaN
# 83787              NaN                    NaN             NaN
# 83788              NaN                    NaN             NaN
# 83789              NaN                    NaN             NaN
#
#               action_label client_is_present client_is_invited
# 0      Business Engagement               1.0               1.0
# 1      Business Engagement               1.0               1.0
# 2      Business Engagement               1.0               1.0
# 3      Business Engagement               1.0               1.0
# 4      Business Engagement               1.0               1.0
# ...                    ...               ...               ...
# 83785                  NaN               NaN               NaN
# 83786                  NaN               NaN               NaN
# 83787                  NaN               NaN               NaN
# 83788                  NaN               NaN               NaN
# 83789                  NaN               NaN               NaN
#
# [83790 rows x 32 columns]

# %%
df.isna().sum().to_frame().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_a44c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a44c1_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a44c1_level0_row0" class="row_heading level0 row0" >client_id</th>
#       <td id="T_a44c1_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row1" class="row_heading level0 row1" >transaction_id</th>
#       <td id="T_a44c1_row1_col0" class="data row1 col0" >4929</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row2" class="row_heading level0 row2" >transaction_date</th>
#       <td id="T_a44c1_row2_col0" class="data row2 col0" >4929</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row3" class="row_heading level0 row3" >product_quantity</th>
#       <td id="T_a44c1_row3_col0" class="data row3 col0" >4929</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row4" class="row_heading level0 row4" >gross_amount_euro</th>
#       <td id="T_a44c1_row4_col0" class="data row4 col0" >4929</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row5" class="row_heading level0 row5" >product_category</th>
#       <td id="T_a44c1_row5_col0" class="data row5 col0" >4929</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row6" class="row_heading level0 row6" >product_subcategory</th>
#       <td id="T_a44c1_row6_col0" class="data row6 col0" >4929</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row7" class="row_heading level0 row7" >product_style</th>
#       <td id="T_a44c1_row7_col0" class="data row7 col0" >4939</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row8" class="row_heading level0 row8" >client_country</th>
#       <td id="T_a44c1_row8_col0" class="data row8 col0" >9491</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row9" class="row_heading level0 row9" >client_gender</th>
#       <td id="T_a44c1_row9_col0" class="data row9 col0" >11886</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row10" class="row_heading level0 row10" >client_nationality</th>
#       <td id="T_a44c1_row10_col0" class="data row10 col0" >11721</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row11" class="row_heading level0 row11" >client_city</th>
#       <td id="T_a44c1_row11_col0" class="data row11 col0" >18331</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row12" class="row_heading level0 row12" >client_segment</th>
#       <td id="T_a44c1_row12_col0" class="data row12 col0" >4929</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row13" class="row_heading level0 row13" >client_premium_status</th>
#       <td id="T_a44c1_row13_col0" class="data row13 col0" >4929</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row14" class="row_heading level0 row14" >client_is_phone_contactable</th>
#       <td id="T_a44c1_row14_col0" class="data row14 col0" >4929</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row15" class="row_heading level0 row15" >client_is_email_contactable</th>
#       <td id="T_a44c1_row15_col0" class="data row15 col0" >4929</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row16" class="row_heading level0 row16" >client_is_instant_messaging_contactable</th>
#       <td id="T_a44c1_row16_col0" class="data row16 col0" >4929</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row17" class="row_heading level0 row17" >client_is_contactable</th>
#       <td id="T_a44c1_row17_col0" class="data row17 col0" >4929</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row18" class="row_heading level0 row18" >action_id</th>
#       <td id="T_a44c1_row18_col0" class="data row18 col0" >11489</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row19" class="row_heading level0 row19" >action_type_label</th>
#       <td id="T_a44c1_row19_col0" class="data row19 col0" >11489</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row20" class="row_heading level0 row20" >action_subcategory_label</th>
#       <td id="T_a44c1_row20_col0" class="data row20 col0" >11489</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row21" class="row_heading level0 row21" >action_start_date</th>
#       <td id="T_a44c1_row21_col0" class="data row21 col0" >11489</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row22" class="row_heading level0 row22" >action_year</th>
#       <td id="T_a44c1_row22_col0" class="data row22 col0" >11489</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row23" class="row_heading level0 row23" >action_end_date</th>
#       <td id="T_a44c1_row23_col0" class="data row23 col0" >11489</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row24" class="row_heading level0 row24" >action_collection_year</th>
#       <td id="T_a44c1_row24_col0" class="data row24 col0" >11489</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row25" class="row_heading level0 row25" >action_collection</th>
#       <td id="T_a44c1_row25_col0" class="data row25 col0" >11504</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row26" class="row_heading level0 row26" >action_universe</th>
#       <td id="T_a44c1_row26_col0" class="data row26 col0" >11489</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row27" class="row_heading level0 row27" >action_category_label</th>
#       <td id="T_a44c1_row27_col0" class="data row27 col0" >11489</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row28" class="row_heading level0 row28" >action_channel</th>
#       <td id="T_a44c1_row28_col0" class="data row28 col0" >22569</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row29" class="row_heading level0 row29" >action_label</th>
#       <td id="T_a44c1_row29_col0" class="data row29 col0" >11489</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row30" class="row_heading level0 row30" >client_is_present</th>
#       <td id="T_a44c1_row30_col0" class="data row30 col0" >11489</td>
#     </tr>
#     <tr>
#       <th id="T_a44c1_level0_row31" class="row_heading level0 row31" >client_is_invited</th>
#       <td id="T_a44c1_row31_col0" class="data row31 col0" >11489</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.dtypes.to_frame().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_f5ae6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5ae6_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5ae6_level0_row0" class="row_heading level0 row0" >client_id</th>
#       <td id="T_f5ae6_row0_col0" class="data row0 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row1" class="row_heading level0 row1" >transaction_id</th>
#       <td id="T_f5ae6_row1_col0" class="data row1 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row2" class="row_heading level0 row2" >transaction_date</th>
#       <td id="T_f5ae6_row2_col0" class="data row2 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row3" class="row_heading level0 row3" >product_quantity</th>
#       <td id="T_f5ae6_row3_col0" class="data row3 col0" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row4" class="row_heading level0 row4" >gross_amount_euro</th>
#       <td id="T_f5ae6_row4_col0" class="data row4 col0" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row5" class="row_heading level0 row5" >product_category</th>
#       <td id="T_f5ae6_row5_col0" class="data row5 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row6" class="row_heading level0 row6" >product_subcategory</th>
#       <td id="T_f5ae6_row6_col0" class="data row6 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row7" class="row_heading level0 row7" >product_style</th>
#       <td id="T_f5ae6_row7_col0" class="data row7 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row8" class="row_heading level0 row8" >client_country</th>
#       <td id="T_f5ae6_row8_col0" class="data row8 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row9" class="row_heading level0 row9" >client_gender</th>
#       <td id="T_f5ae6_row9_col0" class="data row9 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row10" class="row_heading level0 row10" >client_nationality</th>
#       <td id="T_f5ae6_row10_col0" class="data row10 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row11" class="row_heading level0 row11" >client_city</th>
#       <td id="T_f5ae6_row11_col0" class="data row11 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row12" class="row_heading level0 row12" >client_segment</th>
#       <td id="T_f5ae6_row12_col0" class="data row12 col0" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row13" class="row_heading level0 row13" >client_premium_status</th>
#       <td id="T_f5ae6_row13_col0" class="data row13 col0" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row14" class="row_heading level0 row14" >client_is_phone_contactable</th>
#       <td id="T_f5ae6_row14_col0" class="data row14 col0" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row15" class="row_heading level0 row15" >client_is_email_contactable</th>
#       <td id="T_f5ae6_row15_col0" class="data row15 col0" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row16" class="row_heading level0 row16" >client_is_instant_messaging_contactable</th>
#       <td id="T_f5ae6_row16_col0" class="data row16 col0" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row17" class="row_heading level0 row17" >client_is_contactable</th>
#       <td id="T_f5ae6_row17_col0" class="data row17 col0" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row18" class="row_heading level0 row18" >action_id</th>
#       <td id="T_f5ae6_row18_col0" class="data row18 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row19" class="row_heading level0 row19" >action_type_label</th>
#       <td id="T_f5ae6_row19_col0" class="data row19 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row20" class="row_heading level0 row20" >action_subcategory_label</th>
#       <td id="T_f5ae6_row20_col0" class="data row20 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row21" class="row_heading level0 row21" >action_start_date</th>
#       <td id="T_f5ae6_row21_col0" class="data row21 col0" >datetime64[ns]</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row22" class="row_heading level0 row22" >action_year</th>
#       <td id="T_f5ae6_row22_col0" class="data row22 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row23" class="row_heading level0 row23" >action_end_date</th>
#       <td id="T_f5ae6_row23_col0" class="data row23 col0" >datetime64[ns]</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row24" class="row_heading level0 row24" >action_collection_year</th>
#       <td id="T_f5ae6_row24_col0" class="data row24 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row25" class="row_heading level0 row25" >action_collection</th>
#       <td id="T_f5ae6_row25_col0" class="data row25 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row26" class="row_heading level0 row26" >action_universe</th>
#       <td id="T_f5ae6_row26_col0" class="data row26 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row27" class="row_heading level0 row27" >action_category_label</th>
#       <td id="T_f5ae6_row27_col0" class="data row27 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row28" class="row_heading level0 row28" >action_channel</th>
#       <td id="T_f5ae6_row28_col0" class="data row28 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row29" class="row_heading level0 row29" >action_label</th>
#       <td id="T_f5ae6_row29_col0" class="data row29 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row30" class="row_heading level0 row30" >client_is_present</th>
#       <td id="T_f5ae6_row30_col0" class="data row30 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_f5ae6_level0_row31" class="row_heading level0 row31" >client_is_invited</th>
#       <td id="T_f5ae6_row31_col0" class="data row31 col0" >float64</td>
#     </tr>
#   </tbody>
# </table>

# %%
df["action_end_date"] = pd.to_datetime(df["action_end_date"])
df["action_start_date"] = pd.to_datetime(df["action_start_date"])

# %%
df_actions.groupby("action_id").apply(lambda x: len(x["client_id"].value_counts()))
# Out:
# /var/folders/02/4dhz5d9x1k994lg22tygy0zh0000gn/T/ipykernel_57144/238818523.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_actions.groupby("action_id").apply(lambda x: len(x["client_id"].value_counts()))
# action_id
# a000858    76
# a004211     1
# a005065    10
# a005924     1
# a006094     3
#            ..
# a987560    15
# a988444     1
# a993574     1
# a996597     2
# a999183     5
# Length: 564, dtype: int64

# %% [markdown]
# # Recommending Clients who never attended an event before

# %%
df
# Out:
#        client_id transaction_id transaction_date  product_quantity  \
# 0      c17974679      t11288118       2020-07-25                 1
# 1      c17974679      t93389142       2020-06-20                 1
# 2      c17974679      t62924895       2021-01-13                 1
# 3      c17974679      t93389142       2020-06-20                 1
# 4      c17974679      t33368160       2021-05-03                 1
# ...          ...            ...              ...               ...
# 83785  c36938015      t19758562       2021-07-03                 1
# 83786  c19544295      t83687427       2021-12-27                 1
# 83787  c07447234      t31595753       2021-05-27                 1
# 83788  c08145778      t79698899       2021-11-02                 1
# 83789  c54482513      t94462221       2022-01-12                 1
#
#        gross_amount_euro     product_category product_subcategory  \
# 0                   3044  Women Ready-to-Wear             Unknown
# 1                    569      Women Accessory             Unknown
# 2                   7727           Women Bags             Unknown
# 3                   3954  Women Ready-to-Wear             Unknown
# 4                   1541  Women Ready-to-Wear      bottom segment
# ...                  ...                  ...                 ...
# 83785               2220          Woman Shoes             Unknown
# 83786               6472           Women Bags             Unknown
# 83787                111      Women Accessory      bottom segment
# 83788               1220      Women Accessory             Unknown
# 83789                550      Women Accessory             Unknown
#
#          product_style client_country client_gender  ... action_year  \
# 0         Casual Style             DE             F  ...      2020.0
# 1      Stylish Fashion             DE             F  ...      2020.0
# 2              Leather             DE             F  ...      2020.0
# 3         Casual Style             DE             F  ...      2020.0
# 4         Casual Style             DE             F  ...      2020.0
# ...                ...            ...           ...  ...         ...
# 83785   Easy Day Style             DE             M  ...         NaN
# 83786          Leather             JP           NaN  ...         NaN
# 83787    Fashion Style             US             F  ...         NaN
# 83788  Stylish Fashion             AU             F  ...         NaN
# 83789  Stylish Fashion             AE           NaN  ...         NaN
#
#       action_end_date  action_collection_year  action_collection  \
# 0          2020-03-09                  2020.0  Winter Collection
# 1          2020-03-09                  2020.0  Winter Collection
# 2          2020-03-09                  2020.0  Winter Collection
# 3          2020-03-09                  2020.0  Winter Collection
# 4          2020-03-09                  2020.0  Winter Collection
# ...               ...                     ...                ...
# 83785             NaT                     NaN                NaN
# 83786             NaT                     NaN                NaN
# 83787             NaT                     NaN                NaN
# 83788             NaT                     NaN                NaN
# 83789             NaT                     NaN                NaN
#
#        action_universe  action_category_label  action_channel  \
# 0      Women's Fashion                 Client   Outside venue
# 1      Women's Fashion                 Client   Outside venue
# 2      Women's Fashion                 Client   Outside venue
# 3      Women's Fashion                 Client   Outside venue
# 4      Women's Fashion                 Client   Outside venue
# ...                ...                    ...             ...
# 83785              NaN                    NaN             NaN
# 83786              NaN                    NaN             NaN
# 83787              NaN                    NaN             NaN
# 83788              NaN                    NaN             NaN
# 83789              NaN                    NaN             NaN
#
#               action_label client_is_present client_is_invited
# 0      Business Engagement               1.0               1.0
# 1      Business Engagement               1.0               1.0
# 2      Business Engagement               1.0               1.0
# 3      Business Engagement               1.0               1.0
# 4      Business Engagement               1.0               1.0
# ...                    ...               ...               ...
# 83785                  NaN               NaN               NaN
# 83786                  NaN               NaN               NaN
# 83787                  NaN               NaN               NaN
# 83788                  NaN               NaN               NaN
# 83789                  NaN               NaN               NaN
#
# [83790 rows x 32 columns]
